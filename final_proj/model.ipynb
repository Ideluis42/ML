# %% [markdown]
# # Aircraft Accident Prediction Model
#
# ***TO DO: INTRODUCTION***
#
# ## Imports
# The first thing we need to do is import the following packages so we can run the model:
# * `pandas`

# %%
import pandas as pd

# %% [markdown]
# Now we can import the cleaned data. If you haven't cleaned the data yet, you can run through the `cleaning.ipynb` to go through the cleaning steps, or you can download the `cleaned_data.csv` file from here. ***to do : add link***

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
# Out:
#        Unnamed: 0             ev_id acft_missing flt_plan_filed  \
# 0               0  20080107X00026_1        ['N']       ['NONE']
# 1               1  20080107X00026_2        ['N']       ['NONE']
# 2               2  20080107X00027_1        ['N']        ['IFR']
# 3               3  20080109X00036_1        ['N']       ['NONE']
# 4               4  20080111X00038_1        ['N']        ['IFR']
# ...           ...               ...          ...            ...
# 28572       28572  20241029195408_1        ['N']          [nan]
# 28573       28573  20241029195410_1        ['N']          [nan]
# 28574       28574  20241030195412_1        ['N']          [nan]
# 28575       28575  20241030195414_1        ['N']          [nan]
# 28576       28576  20241030195417_1        ['N']          [nan]
#
#       flight_plan_activated    damage acft_fire acft_expl  \
# 0                     [nan]  ['MINR']  ['NONE']  ['NONE']
# 1                     [nan]  ['SUBS']  ['NONE']  ['NONE']
# 2                     ['Y']     [nan]  ['NONE']  ['NONE']
# 3                     ['N']  ['SUBS']  ['NONE']  ['NONE']
# 4                     ['Y']  ['MINR']     [nan]     [nan]
# ...                     ...       ...       ...       ...
# 28572                 [nan]     [nan]     [nan]     [nan]
# 28573                 [nan]     [nan]     [nan]     [nan]
# 28574                 [nan]     [nan]     [nan]     [nan]
# 28575                 [nan]     [nan]     [nan]     [nan]
# 28576                 [nan]     [nan]     [nan]     [nan]
#
#                         acft_make          acft_model  ... crew_inj_level  \
# 0                       ['PIPER']       ['PA 28-180']  ...       ['NONE']
# 1             ['Barnard/Stancil']         ['Glastar']  ...       ['NONE']
# 2                     ['Pilatus']        ['PC-12/45']  ...       ['NONE']
# 3      ['Micco Aircraft Company']        ['MAC-145B']  ...       ['NONE']
# 4                      ['Boeing']         ['737-400']  ...            NaN
# ...                           ...                 ...  ...            ...
# 28572       ['DIERENFIELD DEVIN']           ['RV-6A']  ...            NaN
# 28573         ['GOSSELIN MARK J']  ['ZODIAC 601 HDS']  ...            NaN
# 28574                  ['AIRBUS']    ['A300 F4-622R']  ...            NaN
# 28575                  ['BOEING']             ['787']  ...            NaN
# 28576                  ['SOCATA']         ['TBM 700']  ...            NaN
#
#       pc_profession                            bfr_date med_crtf_limit  \
# 0            ['No']  [Timestamp('2007-07-01 00:00:00')]          [nan]
# 1            ['No']  [Timestamp('2007-07-01 00:00:00')]          [nan]
# 2           ['UNK']  [Timestamp('2007-02-01 00:00:00')]          [nan]
# 3            ['No']  [Timestamp('2006-11-01 00:00:00')]          [nan]
# 4               NaN                                 NaN            NaN
# ...             ...                                 ...            ...
# 28572           NaN                                 NaN            NaN
# 28573           NaN                                 NaN            NaN
# 28574           NaN                                 NaN            NaN
# 28575           NaN                                 NaN            NaN
# 28576           NaN                                 NaN            NaN
#
#       mr_faa_med_certf pilot_flying available_restraint restraint_used  \
# 0                [nan]      [False]               [nan]          [nan]
# 1                [nan]      [False]               [nan]          [nan]
# 2                [nan]      [False]               [nan]          [nan]
# 3                [nan]      [False]               [nan]          [nan]
# 4                  NaN          NaN                 NaN            NaN
# ...                ...          ...                 ...            ...
# 28572              NaN          NaN                 NaN            NaN
# 28573              NaN          NaN                 NaN            NaN
# 28574              NaN          NaN                 NaN            NaN
# 28575              NaN          NaN                 NaN            NaN
# 28576              NaN          NaN                 NaN            NaN
#
#                                      inj_person_category  \
# 0               ['Flig', 'Flig', 'Flig', 'Flig', 'Flig']
# 1      ['Flig', 'Flig', 'Flig', 'Flig', 'Flig', 'Pass...
# 2      ['Flig', 'Flig', 'Flig', 'Flig', 'Flig', 'Pass...
# 3               ['Flig', 'Flig', 'Flig', 'Flig', 'Flig']
# 4                                                    NaN
# ...                                                  ...
# 28572                                                NaN
# 28573                                                NaN
# 28574                                                NaN
# 28575                                                NaN
# 28576                   ['Flig', 'Flig', 'Pass', 'Pass']
#
#                                             injury_level
# 0               ['FATL', 'MINR', 'NONE', 'SERS', 'TOTL']
# 1      ['FATL', 'MINR', 'NONE', 'SERS', 'TOTL', 'NONE...
# 2      ['FATL', 'MINR', 'NONE', 'SERS', 'TOTL', 'NONE...
# 3               ['FATL', 'MINR', 'NONE', 'SERS', 'TOTL']
# 4                                                    NaN
# ...                                                  ...
# 28572                                                NaN
# 28573                                                NaN
# 28574                                                NaN
# 28575                                                NaN
# 28576                   ['MINR', 'TOTL', 'MINR', 'TOTL']
#
# [28577 rows x 75 columns]
